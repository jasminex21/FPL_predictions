# %% [markdown]
# ### Training a Random Forest Regressor model
# Training a random forest regressor that predicts FPL points for the upcoming GW for players. This is a general model, and uses position as one of the predictors. A future step might be to produce a separate model for each position so that position-specific features can be better considered.
#
# Rolling game statistics are key to the model - they will be computed on the previous three games for each player, and used as predictor features.

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score

# %%
data = pd.read_csv("final_data_official.csv")
data
# Out:
#                       name                     club  element  fixture  \
# 0          Aaron Cresswell          West Ham United      454       10
# 1             Aaron Lennon                  Everton      142        3
# 2       Abdoulaye Doucouré                  Watford      482        7
# 3             Adam Forshaw            Middlesbrough      286        6
# 4             Adam Lallana                Liverpool      205        8
# ...                    ...                      ...      ...      ...
# 109075       Justin Hubner  Wolverhampton Wanderers      751      149
# 109076       Justin Hubner  Wolverhampton Wanderers      751      160
# 109077       Justin Hubner  Wolverhampton Wanderers      751      170
# 109078       Justin Hubner  Wolverhampton Wanderers      751      180
# 109079       Justin Hubner  Wolverhampton Wanderers      751      183
#
#         opponent_team  total_points  was_home               kickoff_time  \
# 0                   4             0     False  2016-08-15 19:00:00+00:00
# 1                  17             1      True  2016-08-13 14:00:00+00:00
# 2                  13             0     False  2016-08-13 14:00:00+00:00
# 3                  14             1      True  2016-08-13 14:00:00+00:00
# 4                   1            11     False  2016-08-14 15:00:00+00:00
# ...               ...           ...       ...                        ...
# 109075              6             0      True  2023-12-05 19:30:00+00:00
# 109076             16             0      True  2023-12-09 15:00:00+00:00
# 109077             19             0     False  2023-12-17 14:00:00+00:00
# 109078              7             0      True  2023-12-24 13:00:00+00:00
# 109079              4             0     False  2023-12-27 19:30:00+00:00
#
#         team_h_score  team_a_score  ...  ict_index  value  transfers_balance  \
# 0                2.0           1.0  ...        0.0     55                  0
# 1                1.0           1.0  ...        0.9     60                  0
# 2                1.0           1.0  ...        0.0     50                  0
# 3                1.0           1.0  ...        0.3     45                  0
# 4                3.0           4.0  ...       14.2     70                  0
# ...              ...           ...  ...        ...    ...                ...
# 109075           1.0           0.0  ...        0.0     40                344
# 109076           1.0           1.0  ...        0.0     40                329
# 109077           3.0           0.0  ...        0.0     40                229
# 109078           2.0           1.0  ...        0.0     40                 42
# 109079           1.0           4.0  ...        0.0     40                146
#
#         selected  transfers_in  transfers_out    position     season  \
# 0          14023             0              0    Defender  2016/2017
# 1          13918             0              0  Midfielder  2016/2017
# 2           1051             0              0  Midfielder  2016/2017
# 3           2723             0              0  Midfielder  2016/2017
# 4         155525             0              0  Midfielder  2016/2017
# ...          ...           ...            ...         ...        ...
# 109075       555           375             31    Defender  2023/2024
# 109076      1078           435            106    Defender  2023/2024
# 109077      1583           418            189    Defender  2023/2024
# 109078      1763           197            155    Defender  2023/2024
# 109079      1998           254            108    Defender  2023/2024
#
#         opponent_team_name  result
# 0                  Chelsea       L
# 1        Tottenham Hotspur       D
# 2              Southampton       D
# 3               Stoke City       D
# 4                  Arsenal       W
# ...                    ...     ...
# 109075             Burnley       W
# 109076   Nottingham Forest       D
# 109077     West Ham United       L
# 109078             Chelsea       W
# 109079           Brentford       W
#
# [109080 rows x 37 columns]

# %%
# encoding categorical variables (club, opponent club, position, and result) as integers
club_encoder = LabelEncoder()
opp_encoder = LabelEncoder()
pos_encoder = LabelEncoder()
data["club_encoded"] = club_encoder.fit_transform(data["club"])
data["opponent_encoded"] = opp_encoder.fit_transform(data["opponent_team_name"])
data["position_encoded"] = pos_encoder.fit_transform(data["position"])
# there is inherent ordinality to results - W > D > L
result_mapping = {'W': 2, 'D': 1, 'L': 0}
data['result_encoded'] = data['result'].map(result_mapping)
data
# Out:
#                       name                     club  element  fixture  \
# 0          Aaron Cresswell          West Ham United      454       10
# 1             Aaron Lennon                  Everton      142        3
# 2       Abdoulaye Doucouré                  Watford      482        7
# 3             Adam Forshaw            Middlesbrough      286        6
# 4             Adam Lallana                Liverpool      205        8
# ...                    ...                      ...      ...      ...
# 109075       Justin Hubner  Wolverhampton Wanderers      751      149
# 109076       Justin Hubner  Wolverhampton Wanderers      751      160
# 109077       Justin Hubner  Wolverhampton Wanderers      751      170
# 109078       Justin Hubner  Wolverhampton Wanderers      751      180
# 109079       Justin Hubner  Wolverhampton Wanderers      751      183
#
#         opponent_team  total_points  was_home               kickoff_time  \
# 0                   4             0     False  2016-08-15 19:00:00+00:00
# 1                  17             1      True  2016-08-13 14:00:00+00:00
# 2                  13             0     False  2016-08-13 14:00:00+00:00
# 3                  14             1      True  2016-08-13 14:00:00+00:00
# 4                   1            11     False  2016-08-14 15:00:00+00:00
# ...               ...           ...       ...                        ...
# 109075              6             0      True  2023-12-05 19:30:00+00:00
# 109076             16             0      True  2023-12-09 15:00:00+00:00
# 109077             19             0     False  2023-12-17 14:00:00+00:00
# 109078              7             0      True  2023-12-24 13:00:00+00:00
# 109079              4             0     False  2023-12-27 19:30:00+00:00
#
#         team_h_score  team_a_score  ...  transfers_in  transfers_out  \
# 0                2.0           1.0  ...             0              0
# 1                1.0           1.0  ...             0              0
# 2                1.0           1.0  ...             0              0
# 3                1.0           1.0  ...             0              0
# 4                3.0           4.0  ...             0              0
# ...              ...           ...  ...           ...            ...
# 109075           1.0           0.0  ...           375             31
# 109076           1.0           1.0  ...           435            106
# 109077           3.0           0.0  ...           418            189
# 109078           2.0           1.0  ...           197            155
# 109079           1.0           4.0  ...           254            108
#
#           position     season  opponent_team_name  result  club_encoded  \
# 0         Defender  2016/2017             Chelsea       L            31
# 1       Midfielder  2016/2017   Tottenham Hotspur       D             9
# 2       Midfielder  2016/2017         Southampton       D            29
# 3       Midfielder  2016/2017          Stoke City       D            19
# 4       Midfielder  2016/2017             Arsenal       W            15
# ...            ...        ...                 ...     ...           ...
# 109075    Defender  2023/2024             Burnley       W            32
# 109076    Defender  2023/2024   Nottingham Forest       D            32
# 109077    Defender  2023/2024     West Ham United       L            32
# 109078    Defender  2023/2024             Chelsea       W            32
# 109079    Defender  2023/2024           Brentford       W            32
#
#         opponent_encoded  position_encoded  result_encoded
# 0                      6                 0               0
# 1                     27                 3               1
# 2                     23                 3               1
# 3                     24                 3               1
# 4                      0                 3               2
# ...                  ...               ...             ...
# 109075                 5                 0               2
# 109076                21                 0               1
# 109077                30                 0               0
# 109078                 6                 0               2
# 109079                 3                 0               2
#
# [109080 rows x 41 columns]

# %%
# to compute rolling statistics, we group the dataset by player
players_grp = data.groupby(["name"])
haaland = players_grp.get_group("Erling Haaland")
haaland[["ict_index", "selected"]]
# Out:
#         ict_index  selected
# 69231        14.0   3398599
# 69802         5.5   5226268
# 70381        12.5   5676608
# 70971        19.4   5967805
# 71570        18.9   6793855
# 72174        13.5   7781487
# 72768         6.3   8407273
# 73233        30.5   8548463
# 73868        12.8   8905419
# 74505        15.4   8989666
# 75727        13.6   8983808
# 76372         0.0   8749219
# 77025         9.4   8618103
# 77683         6.4   8992529
# 78346        19.6   9219074
# 79017         6.2   9300515
# 79701         2.7   9337012
# 80472         1.7   9422424
# 80473        10.0   9422424
# 81285        17.6   9443086
# 82002         1.8   9525877
# 82810         3.2   9556620
# 82811         8.1   9556620
# 83609         1.2   9574623
# 84346         8.6   9520984
# 85093         5.2   9582624
# 85857         7.0   9450139
# 87324         0.0   8141991
# 88474        12.3   8645137
# 89225        11.4   9046031
# 90587        21.6   9139028
# 91370        10.7   9452663
# 91371         9.1   9452663
# 92316         5.7   9522804
# 93086         7.5   9510588
# 93928         0.4   9565582
# 93929         8.3   9565582
# 94838         0.0   8939645
# 103799       13.9   7200159
# 103800        6.3   8231668
# 103801       14.4   8571562
# 103802       19.8   8787213
# 103803       17.4   9070132
# 103804        5.9   9176859
# 103805        4.6   9241818
# 103806        3.8   9008161
# 103807        6.6   8880074
# 103808       20.8   8540943
# 103809        2.4   8693052
# 103810       20.3   8445429
# 103811       10.8   8444738
# 103812        6.4   8677883
# 103813        6.4   8714407
# 103814        0.0   8812520
# 103815        0.0   7231415
# 103816        0.0   6260409

# %%
# function that computes assigns rolling averages for `cols` for each group (each player)
def rolling_averages(group, cols, new_cols):
    # sort all data by kickoff time, earliest to latest (ascending)
    group = group.sort_values(["kickoff_time"])
    # a mask that identifies where the season changes
    season_mask = group["season"] != group["season"].shift(1)
    # a cumulative count of season changes
    change_count = season_mask.cumsum()
    # rolling averages separately for each season - window resets if season changes
    group[new_cols] = (
        group.groupby(change_count)[cols]
        .rolling(window=3, closed="left", min_periods=1)
        .mean()
        .reset_index(level=0, drop=True)
    )
    group = group.dropna(subset=new_cols)
    return group

# %%
def rolling_averages_old(group, cols, new_cols):
    # sort data by date, ascending
    group = group.sort_values(["kickoff_time"])
    # compute rolling average - note that `closed = left` means that future data isn't used
    rolling_stats = group[cols].rolling(window = 3, closed = "left", min_periods=1).mean()
    # assign the rolling statistics back to the original dataframe
    group[new_cols] = rolling_stats
    # drop the observations containing missing values to prevent propagation of NaN values
    group = group.dropna(subset = new_cols)
    return group

# %%
data.columns
# Out:
# Index(['name', 'club', 'element', 'fixture', 'opponent_team', 'total_points',
#        'was_home', 'kickoff_time', 'team_h_score', 'team_a_score', 'round',
#        'minutes', 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded',
#        'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards',
#        'red_cards', 'saves', 'bonus', 'bps', 'influence', 'creativity',
#        'threat', 'ict_index', 'value', 'transfers_balance', 'selected',
#        'transfers_in', 'transfers_out', 'position', 'season',
#        'opponent_team_name', 'result', 'club_encoded', 'opponent_encoded',
#        'position_encoded', 'result_encoded'],
#       dtype='object')

# %%
# the cols we want to compute rolling averages for 
cols = ["assists", "clean_sheets", "goals_scored", "goals_conceded", "ict_index", "bps", 
        "minutes", "red_cards", "saves", "selected", "transfers_balance", 
        "result_encoded", "value", "total_points"]
# append "_rolling" onto each column name
new_cols = [f"{col}_rolling" for col in cols]

# %%
rolling_averages(haaland, cols, new_cols).head(20)
# Out:
#                  name             club  element  fixture  opponent_team  \
# 69802  Erling Haaland  Manchester City      318       17              3
# 70381  Erling Haaland  Manchester City      318       28             15
# 70971  Erling Haaland  Manchester City      318       37              7
# 71570  Erling Haaland  Manchester City      318       49             16
# 72174  Erling Haaland  Manchester City      318       51              2
# 72768  Erling Haaland  Manchester City      318       80             20
# 73233  Erling Haaland  Manchester City      318       88             14
# 73868  Erling Haaland  Manchester City      318       97             17
# 74505  Erling Haaland  Manchester City      318      106             12
# 75727  Erling Haaland  Manchester City      318      125              5
# 76372  Erling Haaland  Manchester City      318      137             10
# 77025  Erling Haaland  Manchester City      318      145              9
# 77683  Erling Haaland  Manchester City      318      155              4
# 78346  Erling Haaland  Manchester City      318      167             11
# 79017  Erling Haaland  Manchester City      318      175              8
# 79701  Erling Haaland  Manchester City      318      184              6
# 80472  Erling Haaland  Manchester City      318      196             14
# 80473  Erling Haaland  Manchester City      318       68             18
# 81285  Erling Haaland  Manchester City      318      208             20
# 82002  Erling Haaland  Manchester City      318      219             18
#
#        total_points  was_home               kickoff_time  team_h_score  \
# 69802             5      True  2022-08-13 14:00:00+00:00           4.0
# 70381             6     False  2022-08-21 15:30:00+00:00           3.0
# 70971            17      True  2022-08-27 14:00:00+00:00           4.0
# 71570            17      True  2022-08-31 18:30:00+00:00           6.0
# 72174             9     False  2022-09-03 16:30:00+00:00           1.0
# 72768             6     False  2022-09-17 11:30:00+00:00           0.0
# 73233            23      True  2022-10-02 13:00:00+00:00           6.0
# 73868             6      True  2022-10-08 14:00:00+00:00           4.0
# 74505             2     False  2022-10-16 15:30:00+00:00           1.0
# 75727            13      True  2022-10-22 14:00:00+00:00           3.0
# 76372             0     False  2022-10-29 11:30:00+00:00           0.0
# 77025             5      True  2022-11-05 15:00:00+00:00           2.0
# 77683             1      True  2022-11-12 12:30:00+00:00           1.0
# 78346            13     False  2022-12-28 20:00:00+00:00           1.0
# 79017             6      True  2022-12-31 15:00:00+00:00           1.0
# 79701             2     False  2023-01-05 20:00:00+00:00           0.0
# 80472             2     False  2023-01-14 12:30:00+00:00           2.0
# 80473             6      True  2023-01-19 20:00:00+00:00           4.0
# 81285            17      True  2023-01-22 14:00:00+00:00           3.0
# 82002             2     False  2023-02-05 16:30:00+00:00           1.0
#
#        team_a_score  ...  ict_index_rolling  bps_rolling  minutes_rolling  \
# 69802           0.0  ...          14.000000    48.000000        77.000000
# 70381           3.0  ...           9.750000    32.000000        75.000000
# 70971           2.0  ...          10.666667    30.666667        80.000000
# 71570           0.0  ...          12.466667    39.000000        82.000000
# 72174           1.0  ...          16.933333    60.666667        80.333333
# 72768           3.0  ...          17.266667    62.000000        80.333333
# 73233           3.0  ...          12.900000    47.333333        82.666667
# 73868           0.0  ...          16.766667    54.333333        90.000000
# 74505           0.0  ...          16.533333    51.333333        90.000000
# 75727           1.0  ...          19.566667    41.000000        90.000000
# 76372           1.0  ...          13.933333    25.333333        86.333333
# 77025           1.0  ...           9.666667    17.666667        56.333333
# 77683           2.0  ...           7.666667    26.666667        35.000000
# 78346           3.0  ...           5.266667    10.666667        38.666667
# 79017           1.0  ...          11.800000    27.666667        68.666667
# 79701           1.0  ...          10.733333    26.000000        90.000000
# 80472           1.0  ...           9.500000    24.333333        90.000000
# 80473           2.0  ...           3.533333     8.666667        90.000000
# 81285           0.0  ...           4.800000    10.000000        89.666667
# 82002           0.0  ...           9.766667    36.333333        79.666667
#
#        red_cards_rolling  saves_rolling  selected_rolling  \
# 69802                0.0            0.0      3.398599e+06
# 70381                0.0            0.0      4.312434e+06
# 70971                0.0            0.0      4.767158e+06
# 71570                0.0            0.0      5.623560e+06
# 72174                0.0            0.0      6.146089e+06
# 72768                0.0            0.0      6.847716e+06
# 73233                0.0            0.0      7.660872e+06
# 73868                0.0            0.0      8.245741e+06
# 74505                0.0            0.0      8.620385e+06
# 75727                0.0            0.0      8.814516e+06
# 76372                0.0            0.0      8.959631e+06
# 77025                0.0            0.0      8.907564e+06
# 77683                0.0            0.0      8.783710e+06
# 78346                0.0            0.0      8.786617e+06
# 79017                0.0            0.0      8.943235e+06
# 79701                0.0            0.0      9.170706e+06
# 80472                0.0            0.0      9.285534e+06
# 80473                0.0            0.0      9.353317e+06
# 81285                0.0            0.0      9.393953e+06
# 82002                0.0            0.0      9.429311e+06
#
#        transfers_balance_rolling  result_encoded_rolling  value_rolling  \
# 69802                   0.000000                2.000000     115.000000
# 70381              556968.500000                2.000000     115.500000
# 70971              447084.666667                1.666667     116.000000
# 71570              480293.000000                1.666667     116.666667
# 72174              317286.000000                1.666667     117.333333
# 72768              502273.333333                1.666667     118.000000
# 73233              514079.000000                1.666667     119.000000
# 73868              337170.333333                1.666667     120.000000
# 74505              167291.666667                2.000000     121.000000
# 75727              135821.666667                1.333333     121.666667
# 76372              218493.000000                1.333333     122.000000
# 77025               44174.333333                1.333333     122.000000
# 77683              -20623.000000                2.000000     121.666667
# 78346              -29053.333333                1.333333     121.666667
# 79017              112413.666667                1.333333     121.666667
# 79701              181718.666667                1.000000     122.000000
# 80472               82873.000000                1.666667     122.000000
# 80473               39100.333333                1.000000     122.000000
# 81285               35305.333333                1.333333     122.000000
# 82002               27716.666667                1.333333     122.000000
#
#        total_points_rolling
# 69802             13.000000
# 70381              9.000000
# 70971              8.000000
# 71570              9.333333
# 72174             13.333333
# 72768             14.333333
# 73233             10.666667
# 73868             12.666667
# 74505             11.666667
# 75727             10.333333
# 76372              7.000000
# 77025              5.000000
# 77683              6.000000
# 78346              2.000000
# 79017              6.333333
# 79701              6.666667
# 80472              7.000000
# 80473              3.333333
# 81285              3.333333
# 82002              8.333333
#
# [20 rows x 55 columns]

# %%
player_rolling = data.groupby("name").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
player_rolling
# Out:
#                                 name                    club  element  \
# name
# Aaron Connolly 20124  Aaron Connolly  Brighton & Hove Albion       78
#                20660  Aaron Connolly  Brighton & Hove Albion       78
#                21211  Aaron Connolly  Brighton & Hove Albion       78
#                21770  Aaron Connolly  Brighton & Hove Albion       78
#                22354  Aaron Connolly  Brighton & Hove Albion       78
# ...                              ...                     ...      ...
# Ørjan Nyland   41188    Ørjan Nyland             Aston Villa       35
#                41189    Ørjan Nyland             Aston Villa       35
#                42080    Ørjan Nyland             Aston Villa       35
#                42690    Ørjan Nyland             Aston Villa       35
#                43393    Ørjan Nyland             Aston Villa       35
#
#                       fixture  opponent_team  total_points  was_home  \
# name
# Aaron Connolly 20124       16             14             8     False
#                20660       19             13             2      True
#                21211       32              7             2     False
#                21770       40              6             4     False
#                22354       51             18             0      True
# ...                       ...            ...           ...       ...
# Ørjan Nyland   41188      340             13             0      True
#                41189      180              7             0      True
#                42080      355              6             0     False
#                42690      367             17             0     False
#                43393      370              5             0      True
#
#                                    kickoff_time  team_h_score  team_a_score  \
# name
# Aaron Connolly 20124  2020-09-20 13:00:00+00:00           0.0           3.0
#                20660  2020-09-26 11:30:00+00:00           2.0           3.0
#                21211  2020-10-03 14:00:00+00:00           4.0           2.0
#                21770  2020-10-18 13:00:00+00:00           1.0           1.0
#                22354  2020-10-26 17:30:00+00:00           1.0           1.0
# ...                                         ...           ...           ...
# Ørjan Nyland   41188  2021-05-09 13:05:00+00:00           1.0           3.0
#                41189  2021-05-13 17:00:00+00:00           0.0           0.0
#                42080  2021-05-16 11:00:00+00:00           3.0           2.0
#                42690  2021-05-19 17:00:00+00:00           1.0           2.0
#                43393  2021-05-23 15:00:00+00:00           2.0           1.0
#
#                       ...  ict_index_rolling  bps_rolling  minutes_rolling  \
# name                  ...
# Aaron Connolly 20124  ...           3.400000    -3.000000        45.000000
#                20660  ...           5.150000    12.000000        67.000000
#                21211  ...           4.066667     8.666667        69.000000
#                21770  ...           3.166667    12.000000        75.666667
#                22354  ...           1.866667     7.333333        50.000000
# ...                   ...                ...          ...              ...
# Ørjan Nyland   41188  ...           0.000000     0.000000         0.000000
#                41189  ...           0.000000     0.000000         0.000000
#                42080  ...           0.000000     0.000000         0.000000
#                42690  ...           0.000000     0.000000         0.000000
#                43393  ...           0.000000     0.000000         0.000000
#
#                       red_cards_rolling  saves_rolling  selected_rolling  \
# name
# Aaron Connolly 20124                0.0            0.0      32205.000000
#                20660                0.0            0.0      33617.500000
#                21211                0.0            0.0      40863.666667
#                21770                0.0            0.0      48503.666667
#                22354                0.0            0.0      52418.333333
# ...                                 ...            ...               ...
# Ørjan Nyland   41188                0.0            0.0     281394.333333
#                41189                0.0            0.0     278999.000000
#                42080                0.0            0.0     277527.000000
#                42690                0.0            0.0     276053.000000
#                43393                0.0            0.0     275057.666667
#
#                       transfers_balance_rolling  result_encoded_rolling  \
# name
# Aaron Connolly 20124                   0.000000                0.000000
#                20660                -580.500000                1.000000
#                21211                4121.666667                0.666667
#                21770                3684.666667                0.666667
#                22354                1074.333333                0.333333
# ...                                         ...                     ...
# Ørjan Nyland   41188               -2122.333333                1.000000
#                41189               -2346.666667                1.000000
#                42080               -2471.000000                1.000000
#                42690               -2426.000000                0.333333
#                43393               -2033.333333                1.000000
#
#                       value_rolling  total_points_rolling
# name
# Aaron Connolly 20124           55.0              1.000000
#                20660           55.0              4.500000
#                21211           55.0              3.666667
#                21770           55.0              4.000000
#                22354           55.0              2.666667
# ...                             ...                   ...
# Ørjan Nyland   41188           40.0              0.000000
#                41189           40.0              0.000000
#                42080           40.0              0.000000
#                42690           40.0              0.000000
#                43393           40.0              0.000000
#
# [105566 rows x 55 columns]

# %%
player_rolling = player_rolling.droplevel("name")
player_rolling
# Out:
#                  name                    club  element  fixture  \
# 20124  Aaron Connolly  Brighton & Hove Albion       78       16
# 20660  Aaron Connolly  Brighton & Hove Albion       78       19
# 21211  Aaron Connolly  Brighton & Hove Albion       78       32
# 21770  Aaron Connolly  Brighton & Hove Albion       78       40
# 22354  Aaron Connolly  Brighton & Hove Albion       78       51
# ...               ...                     ...      ...      ...
# 41188    Ørjan Nyland             Aston Villa       35      340
# 41189    Ørjan Nyland             Aston Villa       35      180
# 42080    Ørjan Nyland             Aston Villa       35      355
# 42690    Ørjan Nyland             Aston Villa       35      367
# 43393    Ørjan Nyland             Aston Villa       35      370
#
#        opponent_team  total_points  was_home               kickoff_time  \
# 20124             14             8     False  2020-09-20 13:00:00+00:00
# 20660             13             2      True  2020-09-26 11:30:00+00:00
# 21211              7             2     False  2020-10-03 14:00:00+00:00
# 21770              6             4     False  2020-10-18 13:00:00+00:00
# 22354             18             0      True  2020-10-26 17:30:00+00:00
# ...              ...           ...       ...                        ...
# 41188             13             0      True  2021-05-09 13:05:00+00:00
# 41189              7             0      True  2021-05-13 17:00:00+00:00
# 42080              6             0     False  2021-05-16 11:00:00+00:00
# 42690             17             0     False  2021-05-19 17:00:00+00:00
# 43393              5             0      True  2021-05-23 15:00:00+00:00
#
#        team_h_score  team_a_score  ...  ict_index_rolling  bps_rolling  \
# 20124           0.0           3.0  ...           3.400000    -3.000000
# 20660           2.0           3.0  ...           5.150000    12.000000
# 21211           4.0           2.0  ...           4.066667     8.666667
# 21770           1.0           1.0  ...           3.166667    12.000000
# 22354           1.0           1.0  ...           1.866667     7.333333
# ...             ...           ...  ...                ...          ...
# 41188           1.0           3.0  ...           0.000000     0.000000
# 41189           0.0           0.0  ...           0.000000     0.000000
# 42080           3.0           2.0  ...           0.000000     0.000000
# 42690           1.0           2.0  ...           0.000000     0.000000
# 43393           2.0           1.0  ...           0.000000     0.000000
#
#        minutes_rolling  red_cards_rolling  saves_rolling  selected_rolling  \
# 20124        45.000000                0.0            0.0      32205.000000
# 20660        67.000000                0.0            0.0      33617.500000
# 21211        69.000000                0.0            0.0      40863.666667
# 21770        75.666667                0.0            0.0      48503.666667
# 22354        50.000000                0.0            0.0      52418.333333
# ...                ...                ...            ...               ...
# 41188         0.000000                0.0            0.0     281394.333333
# 41189         0.000000                0.0            0.0     278999.000000
# 42080         0.000000                0.0            0.0     277527.000000
# 42690         0.000000                0.0            0.0     276053.000000
# 43393         0.000000                0.0            0.0     275057.666667
#
#        transfers_balance_rolling  result_encoded_rolling  value_rolling  \
# 20124                   0.000000                0.000000           55.0
# 20660                -580.500000                1.000000           55.0
# 21211                4121.666667                0.666667           55.0
# 21770                3684.666667                0.666667           55.0
# 22354                1074.333333                0.333333           55.0
# ...                          ...                     ...            ...
# 41188               -2122.333333                1.000000           40.0
# 41189               -2346.666667                1.000000           40.0
# 42080               -2471.000000                1.000000           40.0
# 42690               -2426.000000                0.333333           40.0
# 43393               -2033.333333                1.000000           40.0
#
#        total_points_rolling
# 20124              1.000000
# 20660              4.500000
# 21211              3.666667
# 21770              4.000000
# 22354              2.666667
# ...                     ...
# 41188              0.000000
# 41189              0.000000
# 42080              0.000000
# 42690              0.000000
# 43393              0.000000
#
# [105566 rows x 55 columns]

# %%
player_rolling.index = range(player_rolling.shape[0])
player_rolling
# Out:
#                   name                    club  element  fixture  \
# 0       Aaron Connolly  Brighton & Hove Albion       78       16
# 1       Aaron Connolly  Brighton & Hove Albion       78       19
# 2       Aaron Connolly  Brighton & Hove Albion       78       32
# 3       Aaron Connolly  Brighton & Hove Albion       78       40
# 4       Aaron Connolly  Brighton & Hove Albion       78       51
# ...                ...                     ...      ...      ...
# 105561    Ørjan Nyland             Aston Villa       35      340
# 105562    Ørjan Nyland             Aston Villa       35      180
# 105563    Ørjan Nyland             Aston Villa       35      355
# 105564    Ørjan Nyland             Aston Villa       35      367
# 105565    Ørjan Nyland             Aston Villa       35      370
#
#         opponent_team  total_points  was_home               kickoff_time  \
# 0                  14             8     False  2020-09-20 13:00:00+00:00
# 1                  13             2      True  2020-09-26 11:30:00+00:00
# 2                   7             2     False  2020-10-03 14:00:00+00:00
# 3                   6             4     False  2020-10-18 13:00:00+00:00
# 4                  18             0      True  2020-10-26 17:30:00+00:00
# ...               ...           ...       ...                        ...
# 105561             13             0      True  2021-05-09 13:05:00+00:00
# 105562              7             0      True  2021-05-13 17:00:00+00:00
# 105563              6             0     False  2021-05-16 11:00:00+00:00
# 105564             17             0     False  2021-05-19 17:00:00+00:00
# 105565              5             0      True  2021-05-23 15:00:00+00:00
#
#         team_h_score  team_a_score  ...  ict_index_rolling  bps_rolling  \
# 0                0.0           3.0  ...           3.400000    -3.000000
# 1                2.0           3.0  ...           5.150000    12.000000
# 2                4.0           2.0  ...           4.066667     8.666667
# 3                1.0           1.0  ...           3.166667    12.000000
# 4                1.0           1.0  ...           1.866667     7.333333
# ...              ...           ...  ...                ...          ...
# 105561           1.0           3.0  ...           0.000000     0.000000
# 105562           0.0           0.0  ...           0.000000     0.000000
# 105563           3.0           2.0  ...           0.000000     0.000000
# 105564           1.0           2.0  ...           0.000000     0.000000
# 105565           2.0           1.0  ...           0.000000     0.000000
#
#         minutes_rolling  red_cards_rolling  saves_rolling  selected_rolling  \
# 0             45.000000                0.0            0.0      32205.000000
# 1             67.000000                0.0            0.0      33617.500000
# 2             69.000000                0.0            0.0      40863.666667
# 3             75.666667                0.0            0.0      48503.666667
# 4             50.000000                0.0            0.0      52418.333333
# ...                 ...                ...            ...               ...
# 105561         0.000000                0.0            0.0     281394.333333
# 105562         0.000000                0.0            0.0     278999.000000
# 105563         0.000000                0.0            0.0     277527.000000
# 105564         0.000000                0.0            0.0     276053.000000
# 105565         0.000000                0.0            0.0     275057.666667
#
#         transfers_balance_rolling  result_encoded_rolling  value_rolling  \
# 0                        0.000000                0.000000           55.0
# 1                     -580.500000                1.000000           55.0
# 2                     4121.666667                0.666667           55.0
# 3                     3684.666667                0.666667           55.0
# 4                     1074.333333                0.333333           55.0
# ...                           ...                     ...            ...
# 105561               -2122.333333                1.000000           40.0
# 105562               -2346.666667                1.000000           40.0
# 105563               -2471.000000                1.000000           40.0
# 105564               -2426.000000                0.333333           40.0
# 105565               -2033.333333                1.000000           40.0
#
#         total_points_rolling
# 0                   1.000000
# 1                   4.500000
# 2                   3.666667
# 3                   4.000000
# 4                   2.666667
# ...                      ...
# 105561              0.000000
# 105562              0.000000
# 105563              0.000000
# 105564              0.000000
# 105565              0.000000
#
# [105566 rows x 55 columns]

# %%
player_rolling = player_rolling.drop_duplicates()
player_rolling
# Out:
#                   name                    club  element  fixture  \
# 0       Aaron Connolly  Brighton & Hove Albion       78       16
# 1       Aaron Connolly  Brighton & Hove Albion       78       19
# 2       Aaron Connolly  Brighton & Hove Albion       78       32
# 3       Aaron Connolly  Brighton & Hove Albion       78       40
# 4       Aaron Connolly  Brighton & Hove Albion       78       51
# ...                ...                     ...      ...      ...
# 105561    Ørjan Nyland             Aston Villa       35      340
# 105562    Ørjan Nyland             Aston Villa       35      180
# 105563    Ørjan Nyland             Aston Villa       35      355
# 105564    Ørjan Nyland             Aston Villa       35      367
# 105565    Ørjan Nyland             Aston Villa       35      370
#
#         opponent_team  total_points  was_home               kickoff_time  \
# 0                  14             8     False  2020-09-20 13:00:00+00:00
# 1                  13             2      True  2020-09-26 11:30:00+00:00
# 2                   7             2     False  2020-10-03 14:00:00+00:00
# 3                   6             4     False  2020-10-18 13:00:00+00:00
# 4                  18             0      True  2020-10-26 17:30:00+00:00
# ...               ...           ...       ...                        ...
# 105561             13             0      True  2021-05-09 13:05:00+00:00
# 105562              7             0      True  2021-05-13 17:00:00+00:00
# 105563              6             0     False  2021-05-16 11:00:00+00:00
# 105564             17             0     False  2021-05-19 17:00:00+00:00
# 105565              5             0      True  2021-05-23 15:00:00+00:00
#
#         team_h_score  team_a_score  ...  ict_index_rolling  bps_rolling  \
# 0                0.0           3.0  ...           3.400000    -3.000000
# 1                2.0           3.0  ...           5.150000    12.000000
# 2                4.0           2.0  ...           4.066667     8.666667
# 3                1.0           1.0  ...           3.166667    12.000000
# 4                1.0           1.0  ...           1.866667     7.333333
# ...              ...           ...  ...                ...          ...
# 105561           1.0           3.0  ...           0.000000     0.000000
# 105562           0.0           0.0  ...           0.000000     0.000000
# 105563           3.0           2.0  ...           0.000000     0.000000
# 105564           1.0           2.0  ...           0.000000     0.000000
# 105565           2.0           1.0  ...           0.000000     0.000000
#
#         minutes_rolling  red_cards_rolling  saves_rolling  selected_rolling  \
# 0             45.000000                0.0            0.0      32205.000000
# 1             67.000000                0.0            0.0      33617.500000
# 2             69.000000                0.0            0.0      40863.666667
# 3             75.666667                0.0            0.0      48503.666667
# 4             50.000000                0.0            0.0      52418.333333
# ...                 ...                ...            ...               ...
# 105561         0.000000                0.0            0.0     281394.333333
# 105562         0.000000                0.0            0.0     278999.000000
# 105563         0.000000                0.0            0.0     277527.000000
# 105564         0.000000                0.0            0.0     276053.000000
# 105565         0.000000                0.0            0.0     275057.666667
#
#         transfers_balance_rolling  result_encoded_rolling  value_rolling  \
# 0                        0.000000                0.000000           55.0
# 1                     -580.500000                1.000000           55.0
# 2                     4121.666667                0.666667           55.0
# 3                     3684.666667                0.666667           55.0
# 4                     1074.333333                0.333333           55.0
# ...                           ...                     ...            ...
# 105561               -2122.333333                1.000000           40.0
# 105562               -2346.666667                1.000000           40.0
# 105563               -2471.000000                1.000000           40.0
# 105564               -2426.000000                0.333333           40.0
# 105565               -2033.333333                1.000000           40.0
#
#         total_points_rolling
# 0                   1.000000
# 1                   4.500000
# 2                   3.666667
# 3                   4.000000
# 4                   2.666667
# ...                      ...
# 105561              0.000000
# 105562              0.000000
# 105563              0.000000
# 105564              0.000000
# 105565              0.000000
#
# [105566 rows x 55 columns]

# %%
player_rolling.to_csv("player_rolling_final.csv", index=False)

# %%
def make_predictions(data, predictors): 
    # split data
    train = data[data["date"] < "2023-01-01"]
    test = train = data[data["date"] > "2023-01-01"]
    # fit random forest model
    rf.fit(train[predictors], train["targets"])
    # create predictions
    preds = rf.predict(test[predictors])
    # combine predictions with actual results
    combined = pd.DataFrame(dict(actual = test["targets"], prediction = preds), index = test.index)
    # calculate precision
    precision = precision_score(test["targets"], preds)
    return combined, precision

# %%
player_rolling.columns
# Out:
# Index(['name', 'club', 'element', 'fixture', 'opponent_team', 'total_points',
#        'was_home', 'kickoff_time', 'team_h_score', 'team_a_score', 'round',
#        'minutes', 'goals_scored', 'assists', 'clean_sheets', 'goals_conceded',
#        'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards',
#        'red_cards', 'saves', 'bonus', 'bps', 'influence', 'creativity',
#        'threat', 'ict_index', 'value', 'transfers_balance', 'selected',
#        'transfers_in', 'transfers_out', 'position', 'season',
#        'opponent_team_name', 'result', 'club_encoded', 'opponent_encoded',
#        'position_encoded', 'result_encoded', 'assists_rolling',
#        'clean_sheets_rolling', 'goals_scored_rolling',
#        'goals_conceded_rolling', 'ict_index_rolling', 'bps_rolling',
#        'minutes_rolling', 'red_cards_rolling', 'saves_rolling',
#        'selected_rolling', 'transfers_balance_rolling',
#        'result_encoded_rolling', 'value_rolling', 'total_points_rolling'],
#       dtype='object')

# %%
features = ["position_encoded", "club_encoded", "was_home", "opponent_encoded"] + new_cols
target = ["total_points"]

# %%
features
# Out:
# ['position_encoded',
#  'club_encoded',
#  'was_home',
#  'opponent_encoded',
#  'assists_rolling',
#  'clean_sheets_rolling',
#  'goals_scored_rolling',
#  'goals_conceded_rolling',
#  'ict_index_rolling',
#  'bps_rolling',
#  'minutes_rolling',
#  'red_cards_rolling',
#  'saves_rolling',
#  'selected_rolling',
#  'transfers_balance_rolling',
#  'result_encoded_rolling',
#  'value_rolling',
#  'total_points_rolling']

# %%
# splitting the dataset into training, testing, and validation sets
seasons = np.unique(player_rolling["season"])
train_seasons = seasons[:4]
test_seasons = seasons[4:]
train = player_rolling[player_rolling["season"].isin(train_seasons)]
test = player_rolling[player_rolling["season"].isin(test_seasons)]
train_seasons, test_seasons, train.shape, test.shape
# Out:
# (array(['2016/2017', '2017/2018', '2020/2021', '2021/2022'], dtype=object),
#  array(['2022/2023', '2023/2024'], dtype=object),
#  (67168, 55),
#  (38398, 55))

# %%
rf_reg = RandomForestRegressor(max_depth=10, min_samples_leaf=12, min_samples_split=30, n_estimators=600, n_jobs=-1, random_state=21)
rf_reg.fit(train[features], np.ravel(train[target]))
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=12, min_samples_split=30,
#                       n_estimators=600, n_jobs=-1, random_state=21)

# %%
predictions = rf_reg.predict(test[features])

# %%
mae = mean_absolute_error(test[target], predictions)
mse = mean_squared_error(test[target], predictions)
rmse = mean_squared_error(test[target], predictions, squared=False)  # Pass squared=False to get RMSE
r2 = r2_score(test[target], predictions)
explained_variance = explained_variance_score(test[target], predictions)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'R2 Score: {r2}')
print(f'Explained Variance: {explained_variance}')
# Out:
# MAE: 1.0415005594073288
# MSE: 3.8733586128669972
# RMSE: 1.968085011595535
# R2 Score: 0.2937093937261521
# Explained Variance: 0.29375751060741095

# %%
predictions
# Out:
# array([0.09743383, 0.09761317, 0.10202158, ..., 2.19249591, 1.86768639,
#        1.01766534])

# %%
with open("secondary_rf_reg_model.pickle", "wb") as output:
    pickle.dump(rf_reg, output)

# %%
importances = dict(zip(features, rf_reg.feature_importances_))
sorted(importances.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('minutes_rolling', 0.43815972922700475),
#  ('ict_index_rolling', 0.22112648333705545),
#  ('value_rolling', 0.08667050261902932),
#  ('total_points_rolling', 0.062035681366624906),
#  ('selected_rolling', 0.04910096804026523),
#  ('transfers_balance_rolling', 0.035139627352461913),
#  ('opponent_encoded', 0.02886475880528642),
#  ('bps_rolling', 0.02323929960650149),
#  ('club_encoded', 0.01625004371738621),
#  ('result_encoded_rolling', 0.00913422525027533),
#  ('goals_conceded_rolling', 0.007904847131841973),
#  ('was_home', 0.0061767239851049155),
#  ('saves_rolling', 0.005503704702499795),
#  ('position_encoded', 0.0037833102750960005),
#  ('clean_sheets_rolling', 0.0030571205859865167),
#  ('assists_rolling', 0.002259111654604019),
#  ('goals_scored_rolling', 0.0014732807167991062),
#  ('red_cards_rolling', 0.00012058162617679816)]
